# %% [markdown]
# # Make folder called train and inside make folders called closed and open
# ## make all the folders without captilization

# %%
import os

path =".\dataset"
#we shll store all the file names in this list
filelist = []

for root, dirs, files in os.walk(path):
	for file in files:
        #append the file name to the list
		filelist.append(os.path.join(root,file))


#print all the file names
for name in filelist:
    opened = False
    if name == ".\dataset\annotation.txt" or name== ".\dataset\stats_2018_01.ods":
        continue
    filename = name[name.rindex("\\")+1::]
    state = filename.split("_")[4]
    print(state , end=" ")
    if state == '0':
        #eyes closed
        print("closed")
        os.popen("copy {} {}".format(name, ".\\train\closed"))
    else:
        #eyes opened
        print("open")
        os.popen("copy {} {}".format(name, ".\\train\open"))
# Out:
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# 0 closed
# ...

# %% [markdown]
# # WARNING: This code might take a few mins. After running just check the current folder if train/open and train/closed are not empty
